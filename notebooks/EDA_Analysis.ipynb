# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print(project_root)

# %%
from scripts.eda_data_loader import load_data

nav, tx, perf = load_data()

print(nav.shape)
print(tx.shape)
print(perf.shape)

# %%
from scripts.nav_analysis import plot_nav_trends

plot_nav_trends(nav)

# %%
from scripts.nav_analysis import correlation_heatmap

correlation_heatmap(nav)
